# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('datasets/dataset_train.csv')
graphs = df.groupby('Hogwarts House')

# %%
graphs.plot(figsize=(15,3), layout=(2,2))
# Out:
# Hogwarts House
# Gryffindor    AxesSubplot(0.125,0.125;0.775x0.755)
# Hufflepuff    AxesSubplot(0.125,0.125;0.775x0.755)
# Ravenclaw     AxesSubplot(0.125,0.125;0.775x0.755)
# Slytherin     AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
graphs.hist(figsize=(8, 8))
# Out:
# Hogwarts House
# Gryffindor    [[AxesSubplot(0.125,0.725918;0.158163x0.154082...
# Hufflepuff    [[AxesSubplot(0.125,0.725918;0.158163x0.154082...
# Ravenclaw     [[AxesSubplot(0.125,0.725918;0.158163x0.154082...
# Slytherin     [[AxesSubplot(0.125,0.725918;0.158163x0.154082...
# dtype: object
